# %%
import pandas as pd

# %%
df = pd.read_csv("healthcare_dataset.csv")

# %%
# View Data

# %%
print(df.head())
print(df.info())
print(df.shape)
# Out:
#    Patient_ID  Age  Gender  Blood_Pressure  Heart_Rate  Cholesterol_Level  \
# 0           1   51  Female              97          90                282
# 1           2   92   Other             129          80                169
# 2           3   14    Male             172          76                157
# 3           4   71  Female             131          82                150
# 4           5   60    Male             130          96                206
#
#     BMI                Diagnosis Treatment_Plan Follow_Up_Date
# 0  35.2             Hypertension    Observation     2024-01-01
# 1  32.3                  Healthy     Medication     2024-01-02
# 2  29.9                 Diabetes    Observation     2024-01-03
# 3  19.4  Coronary Artery Disease        Surgery     2024-01-04
# 4  39.3                 Diabetes            NaN     2024-01-05
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         500 non-null    int64
#  1   Age                500 non-null    int64
#  2   Gender             500 non-null    object
#  3   Blood_Pressure     500 non-null    int64
#  4   Heart_Rate         500 non-null    int64
#  5   Cholesterol_Level  500 non-null    int64
#  6   BMI                500 non-null    float64
#  7   Diagnosis          500 non-null    object
#  8   Treatment_Plan     405 non-null    object
#  9   Follow_Up_Date     500 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 39.2+ KB
# None
# (500, 10)

# %%
# Checking Missing Values

# %%
print(df.isnull().sum())
# Out:
# Patient_ID            0
# Age                   0
# Gender                0
# Blood_Pressure        0
# Heart_Rate            0
# Cholesterol_Level     0
# BMI                   0
# Diagnosis             0
# Treatment_Plan       95
# Follow_Up_Date        0
# dtype: int64

# %%
df['Treatment_Plan'] = df['Treatment_Plan'].fillna('Unknown')

# %%
print(df.isnull().sum())
# Out:
# Patient_ID           0
# Age                  0
# Gender               0
# Blood_Pressure       0
# Heart_Rate           0
# Cholesterol_Level    0
# BMI                  0
# Diagnosis            0
# Treatment_Plan       0
# Follow_Up_Date       0
# dtype: int64

# %%
# Removing Duplicates

# %%
print("Before:", df.shape)
# Out:
# Before: (500, 10)

# %%
df = df.drop_duplicates()

# %%
print("After:", df.shape)
# Out:
# After: (500, 10)

# %%
# Fix Data Types

# %%
df["Follow_Up_Date"] = pd.to_datetime(df["Follow_Up_Date"], errors = "coerce" )

# %%
df["Follow_Up_Date"]
# Out:
# 0     2024-01-01
# 1     2024-01-02
# 2     2024-01-03
# 3     2024-01-04
# 4     2024-01-05
#          ...
# 495   2025-05-10
# 496   2025-05-11
# 497   2025-05-12
# 498   2025-05-13
# 499   2025-05-14
# Name: Follow_Up_Date, Length: 500, dtype: datetime64[ns]

# %%
# Handling Missing Values
# Numeric Columns
# Categorical Columns

# %%
numeric_cols = ['Age', 'Blood_Pressure', 'Heart_Rate', 'Cholesterol_Level', 'BMI']

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df[numeric_cols].isnull().sum()
# Out:
# Age                  0
# Blood_Pressure       0
# Heart_Rate           0
# Cholesterol_Level    0
# BMI                  0
# dtype: int64

# %%
categorical_cols = [
    'Gender',
    'Diagnosis',
    'Treatment_Plan'
    
]

for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df[categorical_cols].isnull().sum()
# Out:
# Gender            0
# Diagnosis         0
# Treatment_Plan    0
# dtype: int64

# %%
# Check Invalid Values

# %%
df = df[df["Age"] > 0]

# %%
df
# Out:
#      Patient_ID  Age  Gender  Blood_Pressure  Heart_Rate  Cholesterol_Level  \
# 0             1   51  Female              97          90                282
# 1             2   92   Other             129          80                169
# 2             3   14    Male             172          76                157
# 3             4   71  Female             131          82                150
# 4             5   60    Male             130          96                206
# ..          ...  ...     ...             ...         ...                ...
# 495         496   62   Other             151          88                222
# 496         497   68   Other             169          69                198
# 497         498   21  Female             177          71                185
# 498         499   92  Female             172          89                275
# 499         500   66   Other              97          60                217
#
#       BMI                Diagnosis     Treatment_Plan Follow_Up_Date
# 0    35.2             Hypertension        Observation     2024-01-01
# 1    32.3                  Healthy         Medication     2024-01-02
# 2    29.9                 Diabetes        Observation     2024-01-03
# 3    19.4  Coronary Artery Disease            Surgery     2024-01-04
# 4    39.3                 Diabetes            Unknown     2024-01-05
# ..    ...                      ...                ...            ...
# 495  27.6                  Healthy         Medication     2025-05-10
# 496  27.3                  Healthy  Lifestyle Changes     2025-05-11
# 497  38.0             Hypertension        Observation     2025-05-12
# 498  33.9             Hypertension         Medication     2025-05-13
# 499  31.6                 Diabetes            Unknown     2025-05-14
#
# [491 rows x 10 columns]

# %%
df = df[df["BMI"] > 10]

# %%
df
# Out:
#      Patient_ID  Age  Gender  Blood_Pressure  Heart_Rate  Cholesterol_Level  \
# 0             1   51  Female              97          90                282
# 1             2   92   Other             129          80                169
# 2             3   14    Male             172          76                157
# 3             4   71  Female             131          82                150
# 4             5   60    Male             130          96                206
# ..          ...  ...     ...             ...         ...                ...
# 495         496   62   Other             151          88                222
# 496         497   68   Other             169          69                198
# 497         498   21  Female             177          71                185
# 498         499   92  Female             172          89                275
# 499         500   66   Other              97          60                217
#
#       BMI                Diagnosis     Treatment_Plan Follow_Up_Date
# 0    35.2             Hypertension        Observation     2024-01-01
# 1    32.3                  Healthy         Medication     2024-01-02
# 2    29.9                 Diabetes        Observation     2024-01-03
# 3    19.4  Coronary Artery Disease            Surgery     2024-01-04
# 4    39.3                 Diabetes            Unknown     2024-01-05
# ..    ...                      ...                ...            ...
# 495  27.6                  Healthy         Medication     2025-05-10
# 496  27.3                  Healthy  Lifestyle Changes     2025-05-11
# 497  38.0             Hypertension        Observation     2025-05-12
# 498  33.9             Hypertension         Medication     2025-05-13
# 499  31.6                 Diabetes            Unknown     2025-05-14
#
# [491 rows x 10 columns]

# %%
# Diagnosis Count

# %%
print(df['Diagnosis'].value_counts())
# Out:
# Diagnosis
# Healthy                    104
# Coronary Artery Disease     99
# Hyperlipidemia              99
# Hypertension                98
# Diabetes                    91
# Name: count, dtype: int64

# %%
# Average Cholestrol

# %%
print(df['Cholesterol_Level'].mean())
# Out:
# 226.14052953156823

# %%
# Blood Pressure Count

# %%
print(df['Blood_Pressure'].value_counts())
# Out:
# Blood_Pressure
# 140    13
# 129    12
# 115    11
# 118    11
# 151    10
#        ..
# 117     1
# 166     1
# 137     1
# 147     1
# 169     1
# Name: count, Length: 90, dtype: int64

# %%
# Gender Distribution

# %%
print(df['Gender'].value_counts())
# Out:
# Gender
# Male      184
# Female    159
# Other     148
# Name: count, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         491 non-null    int64
#  1   Age                491 non-null    int64
#  2   Gender             491 non-null    object
#  3   Blood_Pressure     491 non-null    int64
#  4   Heart_Rate         491 non-null    int64
#  5   Cholesterol_Level  491 non-null    int64
#  6   BMI                491 non-null    float64
#  7   Diagnosis          491 non-null    object
#  8   Treatment_Plan     491 non-null    object
#  9   Follow_Up_Date     491 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 42.2+ KB
# None

# %%
df.to_csv("cleaned_healthcare_dataset.csv", index = False)
